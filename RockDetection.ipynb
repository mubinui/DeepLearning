# %% [markdown]
# <a href="https://colab.research.google.com/github/mubinui/DeepLearning/blob/main/RockDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##Rock Detection with **YOLO**
# Mounting google drive for saving the data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Folder structure shell command  
# !ls '/content/drive/MyDrive/yolo_rock_model'
# Out:
# darknet  rock_dataset

# %% [markdown]
# Shell command for **unzipping** the files to a certain folder

# %%
#!unzip '/content/drive/MyDrive/yolo_rock_model/rock_dataset.zip' -d '/content/drive/MyDrive/yolo_rock_model'
# Out:
# Archive:  /content/drive/MyDrive/yolo_rock_model/rock_dataset.zip
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/0 (2).jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/0 (3).jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/0.jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/0.txt
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/00096180014947910921026.jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/00096180014947910921026.txt
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/05819280015911796649727.jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/05819280015911796649727.txt
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/09624110015898065506629.jpg
#   inflating: /content/drive/MyDrive/yolo_rock_model/rock_dataset/09624110015898065506629.txt
# ...

# %% [markdown]
# ##Clonning **Darknet**

# %%
# !git clone 'http://github.com/AlexeyAB/darknet.git' '/content/drive/MyDrive/yolo_rock_model/darknet'
# Out:
# Cloning into '/content/drive/MyDrive/yolo_rock_model/darknet'...
# ...
# remote: Enumerating objects: 15376, done.
# remote: Total 15376 (delta 0), reused 0 (delta 0), pack-reused 15376
# Receiving objects: 100% (15376/15376), 13.98 MiB | 5.67 MiB/s, done.
# Resolving deltas: 100% (10341/10341), done.
# Checking out files: 100% (2050/2050), done.

# %%
# %cd /content/drive/MyDrive/yolo_rock_model/darknet
# Out:
# /content/drive/MyDrive/yolo_rock_model/darknet

# %%
# !ls
# Out:
# 3rdparty		darknet_video.py       net_cam_v4.sh
# build			data		       README.md
# build.ps1		image_yolov3.sh        results
# cfg			image_yolov4.sh        scripts
# cmake			include		       src
# CMakeLists.txt		json_mjpeg_streams.sh  vcpkg.json
# DarknetConfig.cmake.in	LICENSE		       video_yolov3.sh
# darknet_images.py	Makefile	       video_yolov4.sh
# darknet.py		net_cam_v3.sh

# %% [markdown]
# Creating **make file** for compiling the model

# %%
# !make
# Out:
# chmod +x *.sh
# g++ -std=c++11 -std=c++11 -Iinclude/ -I3rdparty/stb/include -DOPENCV `pkg-config --cflags opencv4 2> /dev/null || pkg-config --cflags opencv` -DGPU -I/usr/local/cuda/include/ -DCUDNN -Wall -Wfatal-errors -Wno-unused-result -Wno-unknown-pragmas -fPIC -Ofast -DOPENCV -DGPU -DCUDNN -I/usr/local/cudnn/include -c ./src/image_opencv.cpp -o obj/image_opencv.o
# ./src/image_opencv.cpp: In function ‘void draw_detections_cv_v3(void**, detection*, int, float, char**, image**, int, int)’:
# ./src/image_opencv.cpp:946:23: warning: variable ‘rgb’ set but not used [-Wunused-but-set-variable]
#                  float rgb[3];
#                        ^~~
# ./src/image_opencv.cpp: In function ‘void draw_train_loss(char*, void**, int, float, float, int, int, float, int, char*, float, int, int, double)’:
# ./src/image_opencv.cpp:1147:13: warning: this ‘if’ clause does not guard... [-Wmisleading-indentation]
#              if (iteration_old == 0)
#              ^~
# ...

# %% [markdown]
# Create makefile and editing the values from the **Darknet** folder

# %%
# %cd /content/drive/MyDrive/yolo_rock_model
# Out:
# /content/drive/MyDrive/yolo_rock_model

# %%
# !python rock_dataset/creating-files-data-and-name.py

# %%
# !python rock_dataset/creating-train-and-test-txt-files.py

# %%
# !darknet/darknet detector train rock_dataset/labelled_data.data darknet/cfg/yolov4-tiny-custom.cfg custom_weight/darknet53.conv.74 -dont_show
# Out:
# Streaming output truncated to the last 5000 lines.
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.752535), count: 84, class_loss = 0.543001, iou_loss = 0.197178, total_loss = 0.740179
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.498869), count: 3, class_loss = 0.038356, iou_loss = 0.051228, total_loss = 0.089584
#  total_bbox = 166497, rewritten_bbox = 0.000000 %
#
#  2154: 0.291088, 0.267062 avg loss, 0.002610 rate, 1.481688 seconds, 137856 images, 204.043050 hours left
# Loaded: 0.000115 seconds
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 30 Avg (IOU: 0.764844), count: 84, class_loss = 0.550418, iou_loss = 0.253719, total_loss = 0.804137
# v3 (iou loss, Normalizer: (iou: 0.07, obj: 1.00, cls: 1.00) Region 37 Avg (IOU: 0.456801), count: 4, class_loss = 0.056821, iou_loss = 0.066831, total_loss = 0.123652
#  total_bbox = 166585, rewritten_bbox = 0.000000 %
#
# ...
